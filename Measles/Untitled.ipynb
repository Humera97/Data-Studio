# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile
import xlrd
pd.options.display.max_rows = 300
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
df = pd.read_csv('Measles - data.csv')

# %%
df.head()
# Out:
#        Reporting Area  MMWR Year  MMWR Week  Malaria, Current week  \
# 0              ALASKA       2019          1                    NaN
# 1        PENNSYLVANIA       2019          1                    NaN
# 2  WEST SOUTH CENTRAL       2019          1                    NaN
# 3             INDIANA       2019          1                    NaN
# 4      AMERICAN SAMOA       2019          1                    NaN
#
#    Malaria, Previous 52 weeks Max†  Malaria, Cum 2019†  \
# 0                                1.0                   NaN
# 1                                8.0                   NaN
# 2                                5.0                   NaN
# 3                                1.0                   NaN
# 4                                0.0                   NaN
#
#   Malaria, Cum 2019†, flag  Malaria, Cum 2018† Malaria, Cum 2018†, flag  \
# 0                          -                   NaN                          -
# ...

# %%
df['Reporting Area'] = df['Reporting Area'].str.title()

# %%
df.to_csv('measles.csv', index = False)

# %%
df['Reporting Area'].head()
# Out:
# 0                Alaska
# 1          Pennsylvania
# 2    West South Central
# 3               Indiana
# 4        American Samoa
# Name: Reporting Area, dtype: object

# %%
df.columns
# Out:
# Index(['Reporting Area', 'MMWR Year', 'MMWR Week', 'Malaria, Current week',
#        'Malaria, Previous 52 weeks Max†', 'Malaria, Cum 2019†',
#        'Malaria, Cum 2019†, flag', 'Malaria, Cum 2018†',
#        'Malaria, Cum 2018†, flag', 'Measles§, Idigenousis, Current week',
#        'Measles§, Idigenousis, Current week, flag',
#        'Measles§, Idigenousis, Previous 52 weeks Max†',
#        'Measles§, Idigenousis, Previous 52 weeks Max†, flag',
#        'Measles§, Idigenousis, Cum 2019†',
#        'Measles§, Idigenousis, Cum 2019†, flag',
#        'Measles§, Idigenousis, Cum 2018†',
#        'Measles§, Idigenousis, Cum 2018†, flag',
#        'Measles§, Imported, Current week',
#        'Measles§, Imported, Current week, flag',
#        'Measles§, Imported, Previous 52 weeks Max†',
#        'Measles§, Imported, Previous 52 weeks Max†, flag',
#        'Measles§, Imported, Cum 2019†',
#        'Measles§, Imported, Cum 2019†, flag',
# ...

# %%
df.sort_values(by='Measles§, Idigenousis, Previous 52 weeks Max†', ascending = False)
# Out:
#                 Reporting Area  MMWR Year  MMWR Week  Malaria, Current week  \
# 2099                     Total       2019         30                   18.0
# 2030              Us Residents       2019         30                   18.0
# 1960              Us Residents       2019         29                   22.0
# 1750              Us Residents       2019         26                   16.0
# 1820              Us Residents       2019         27                   10.0
# 1889                     Total       2019         27                   10.0
# 1890              Us Residents       2019         28                   18.0
# 1959                     Total       2019         28                   18.0
# 1819                     Total       2019         26                   16.0
# 2029                     Total       2019         29                   22.0
# 1749                     Total       2019         25                    7.0
# ...

# %%
df.drop(columns = ['Reporting Area', 'MMWR Year', 'MMWR Week', 'Malaria, Current week',
       'Malaria, Previous 52 weeks Max†', 'Malaria, Cum 2019†',
       'Malaria, Cum 2019†, flag', 'Malaria, Cum 2018†',
       'Malaria, Cum 2018†, flag'])

# %%
df.groupby(by='Reporting Area', as_index = False)['Measles§, Idigenousis, Current week, flag'].sum()
# Out:
#               Reporting Area Measles§, Idigenousis, Current week, flag
# 0                    Alabama             ------------------------------
# 1                     Alaska             ------------------------------
# 2             American Samoa             ------------------------------
# 3                    Arizona             ------------------------------
# 4                   Arkansas             ------------------------------
# 5                 California             ------------------------------
# 6                   Colorado             ------------------------------
# 7                Connecticut             ------------------------------
# 8                   Delaware             ------------------------------
# 9       District Of Columbia             ------------------------------
# 10        East North Central             ------------------------------
# 11        East South Central                                        NaN
# ...
