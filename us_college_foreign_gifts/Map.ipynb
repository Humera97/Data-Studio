# %%
import requests
import json
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
pd.options.display.max_rows = 300
import requests
import re
from bs4 import BeautifulSoup

# %%
with open('newcountry.json') as json_data:
    geometry_data = json.load(json_data)

# %%
df = pd.DataFrame.from_dict(json_normalize(geometry_data['features']), orient='columns')

# %%
df.head()
# Out:
#                                 geometry.coordinates geometry.type  \
# 0  [[[[31.287890625000017, -22.40205078125001], [...  MultiPolygon
# 1  [[[[30.39609375, -15.64306640625], [30.2506835...  MultiPolygon
# 2  [[[[53.08564453125001, 16.648388671874997], [5...  MultiPolygon
# 3  [[[[104.06396484375, 10.390820312499997], [104...  MultiPolygon
# 4  [[[[-60.821191406249994, 9.138378906249997], [...  MultiPolygon
#
#   properties.ABBREV  properties.ABBREV_LEN properties.ADM0_A3  \
# 0             Zimb.                      5                ZWE
# 1            Zambia                      6                ZMB
# 2              Yem.                      4                YEM
# 3             Viet.                      5                VNM
# 4              Ven.                      4                VEN
#
#   properties.ADM0_A3_IS  properties.ADM0_A3_UN properties.ADM0_A3_US  \
# 0                   ZWE                    -99                   ZWE
# ...

# %%
df.columns
# Out:
# Index(['geometry.coordinates', 'geometry.type', 'properties.ABBREV',
#        'properties.ABBREV_LEN', 'properties.ADM0_A3', 'properties.ADM0_A3_IS',
#        'properties.ADM0_A3_UN', 'properties.ADM0_A3_US',
#        'properties.ADM0_A3_WB', 'properties.ADM0_DIF', 'properties.ADMIN',
#        'properties.BRK_A3', 'properties.BRK_DIFF', 'properties.BRK_GROUP',
#        'properties.BRK_NAME', 'properties.CONTINENT', 'properties.ECONOMY',
#        'properties.FIPS_10_', 'properties.FORMAL_EN', 'properties.FORMAL_FR',
#        'properties.GDP_MD_EST', 'properties.GDP_YEAR', 'properties.GEOUNIT',
#        'properties.GEOU_DIF', 'properties.GU_A3', 'properties.HOMEPART',
#        'properties.INCOME_GRP', 'properties.ISO_A2', 'properties.ISO_A3',
#        'properties.ISO_A3_EH', 'properties.ISO_N3', 'properties.LABELRANK',
#        'properties.LASTCENSUS', 'properties.LEVEL', 'properties.LONG_LEN',
#        'properties.MAPCOLOR13', 'properties.MAPCOLOR7', 'properties.MAPCOLOR8',
# ...

# %%
df['properties.NAME']
# Out:
# 0                       Zimbabwe
# 1                         Zambia
# 2                          Yemen
# 3                        Vietnam
# 4                      Venezuela
# 5                        Vatican
# 6                        Vanuatu
# 7                     Uzbekistan
# 8                        Uruguay
# 9                     Micronesia
# 10                  Marshall Is.
# 11                N. Mariana Is.
# 12               U.S. Virgin Is.
# 13                          Guam
# 14                American Samoa
# 15                   Puerto Rico
# 16      United States of America
# 17           S. Geo. and the Is.
# 18         Br. Indian Ocean Ter.
# 19                  Saint Helena
# 20                  Pitcairn Is.
# 21                      Anguilla
# 22                  Falkland Is.
# 23                    Cayman Is.
# 24                       Bermuda
# 25            British Virgin Is.
# 26          Turks and Caicos Is.
# 27                    Montserrat
# ...

# %%
df = df[['geometry.coordinates','geometry.type', 'properties.NAME','type']]

# %%
df_data = pd.read_csv("countrygift.csv",encoding = 'latin-1')

# %%
df = df.rename(index=str, columns={
    'properties.NAME' : 'properties.Country'
})

# %%
df_data = df_data.rename(index=str, columns={
    'Country of Giftor' : 'properties.Country'
})

# %%
df['properties.Country'] = df['properties.Country'].str.upper()

# %%
df.head()
# Out:
#                                 geometry.coordinates geometry.type  \
# 0  [[[[31.287890625000017, -22.40205078125001], [...  MultiPolygon
# 1  [[[[30.39609375, -15.64306640625], [30.2506835...  MultiPolygon
# 2  [[[[53.08564453125001, 16.648388671874997], [5...  MultiPolygon
# 3  [[[[104.06396484375, 10.390820312499997], [104...  MultiPolygon
# 4  [[[[-60.821191406249994, 9.138378906249997], [...  MultiPolygon
#
#   properties.Country     type
# 0           ZIMBABWE  Feature
# 1             ZAMBIA  Feature
# 2              YEMEN  Feature
# 3            VIETNAM  Feature
# 4          VENEZUELA  Feature

# %%
df_data.head()
# Out:
#   properties.Country    contract  monetary_gift  real_estate       total
# 0        AFGHANISTAN   5001410.0      3890364.0          0.0   8891774.0
# 1             ANGOLA    499908.0            0.0          0.0    499908.0
# 2          ARGENTINA   1490733.0      3965425.0          0.0   5456158.0
# 3          AUSTRALIA  37268805.0     24187528.0          0.0  61456333.0
# 4            AUSTRIA  15553197.0      3772945.0          0.0  19326142.0

# %%
df['properties.Country'].sort_values(ascending = True)
# Out:
# 237                  AFGHANISTAN
# 236                      ALBANIA
# 235                      ALGERIA
# 14                AMERICAN SAMOA
# 234                      ANDORRA
# 233                       ANGOLA
# 21                      ANGUILLA
# 239                   ANTARCTICA
# 232            ANTIGUA AND BARB.
# 231                    ARGENTINA
# 230                      ARMENIA
# 97                         ARUBA
# 229      ASHMORE AND CARTIER IS.
# 225                    AUSTRALIA
# 224                      AUSTRIA
# 223                   AZERBAIJAN
# 222                      BAHAMAS
# 221                      BAHRAIN
# 220                   BANGLADESH
# 219                     BARBADOS
# 218                      BELARUS
# 217                      BELGIUM
# 216                       BELIZE
# 215                        BENIN
# 24                       BERMUDA
# 214                       BHUTAN
# 213                      BOLIVIA
# 212             BOSNIA AND HERZ.
# ...

# %%
df_data['properties.Country'].sort_values(ascending = True)
# Out:
# 0                   AFGHANISTAN
# 1                        ANGOLA
# 2                     ARGENTINA
# 104                     ARMENIA
# 3                     AUSTRALIA
# 4                       AUSTRIA
# 105                  AZERBAIJAN
# 5                       BAHAMAS
# 6                       BAHRAIN
# 7                    BANGLADESH
# 106                    BARBADOS
# 107                     BELARUS
# 8                       BELGIUM
# 9                       BERMUDA
# 108                     BOLIVIA
# 109      BOSNIA AND HERZEGOVINA
# 110          BOSNIA-HERCEGOVINA
# 10                     BOTSWANA
# 11                       BRAZIL
# 12          BRITISH WEST INDIES
# 13                     BULGARIA
# 14                        BURMA
# 15                       CANADA
# 16         CAYMAN ISLANDS (THE)
# 17                       CEYLON
# 18                        CHILE
# 19                        CHINA
# 20                     COLOMBIA
# 21                   COSTA RICA
# ...

# %%
df2['properties.Country'].sort_values(ascending = True)
# Out:
# 4    VENEZUELA
# 3      VIETNAM
# 2        YEMEN
# 1       ZAMBIA
# 0     ZIMBABWE
# Name: properties.Country, dtype: object

# %%
df['properties.Country'] = df['properties.Country'].str.replace('UNITED STATES OF AMERICA', 'USA', regex = True)

# %%
df['properties.Country'] = df['properties.Country'].str.replace('TRINIDAD AND TOBAGO', 'TRINIDAD', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('ENGLAND', 'UNITED KINGDOM', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('WALES', 'UNITED KINGDOM', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('SCOTLAND', 'UNITED KINGDOM', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('SYRIAN ARAB REPUBLIC', 'SYRIA', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('ST. LUCIA', 'SAINT LUCIA', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('PALESTINE, STATE OF', 'PALESTINE', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('THE NETHERLANDS', 'NETHERLANDS', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('MARSHAL ISLANDS (THE)', 'MARSHALL IS.', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('KOREA', 'SOUTH KOREA', regex = True)

# %%
df['properties.Country'] = df['properties.Country'].str.replace('DOMINICAN REP.', 'DOMINICAN REPUBLIC', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('KOREA', 'SOUTH KOREA', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('BOSNIA-HERCEGOVINA','BOSNIA AND HERZ.', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('BOSNIA AND HERZEGOVINA','BOSNIA AND HERZ.', regex = True)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('VIRGIN ISLANDS (BRITISH)','BRITISH VIRGIN IS.')

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('SOUTH SOUTH SOUTH KOREA','SOUTH KOREA')

# %%
df['properties.Country'] = df['properties.Country'].str.replace('MARSHALL IS.','MARSHAL ISLANDS (THE)')

# %%
df['properties.Country'] = df['properties.Country'].str.replace('BRITISH VIRGIN IS.','VIRGIN ISLANDS (BRITISH)')

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('SOUTH SOUTH KOREA','SOUTH KOREA')

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('CURAÃ§AO','CURAÇAO')

# %%
df['properties.Country'] = df['properties.Country'].str.replace('ESWATINI','SWAZILAND')

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('CZECH REPUBLIC','CZECHIA')

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('CEYLON','SRI LANKA')

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.replace('BURMA','MYANMAR')

# %%
df['properties.Country'] = df['properties.Country'].str.replace('CAYMAN IS.','CAYMAN ISLANDS (THE)')

# %%
df_data.dtypes
# Out:
# properties.Country     object
# contract              float64
# monetary_gift         float64
# real_estate           float64
# total                 float64
# dtype: object

# %%
df.dtypes
# Out:
# geometry.coordinates    object
# geometry.type           object
# properties.Country      object
# type                    object
# dtype: object

# %%
df.loc[df['properties.Country']=='INDIA','properties.Country']
# Out:
# 144    INDIA
# Name: properties.Country, dtype: object

# %%
df_data.loc[df_data['properties.Country']=='INDIA','properties.Country']
# Out:
# 42    INDIA
# Name: properties.Country, dtype: object

# %%
df_data['properties.Country'] = df_data['properties.Country'].astype(str)
df['properties.Country'] = df['properties.Country'].astype(str)

# %%
df_data['properties.Country'] = df_data['properties.Country'].str.strip()

# %%
df['properties.Country'] = df['properties.Country'].str.strip()

# %%
df2 = df.merge(df_data,on=['properties.Country'], how = 'left')

# %%
df2
# Out:
#                                   geometry.coordinates geometry.type  \
# 0    [[[[31.287890625000017, -22.40205078125001], [...  MultiPolygon
# 1    [[[[30.39609375, -15.64306640625], [30.2506835...  MultiPolygon
# 2    [[[[53.08564453125001, 16.648388671874997], [5...  MultiPolygon
# 3    [[[[104.06396484375, 10.390820312499997], [104...  MultiPolygon
# 4    [[[[-60.821191406249994, 9.138378906249997], [...  MultiPolygon
# 5    [[[[12.439160156250011, 41.898388671875], [12....  MultiPolygon
# 6    [[[[166.74580078125, -14.826855468750011], [16...  MultiPolygon
# 7    [[[[70.94677734375, 42.248681640624994], [70.9...  MultiPolygon
# 8    [[[[-53.37060546875, -33.7421875], [-53.419580...  MultiPolygon
# 9    [[[[162.98320312500005, 5.325732421874989], [1...  MultiPolygon
# 10   [[[[169.63505859375005, 5.830078125], [169.615...  MultiPolygon
# 11   [[[[145.70839843750002, 18.7625], [145.678125,...  MultiPolygon
# 12   [[[[-64.84501953124999, 18.330078125], [-64.91...  MultiPolygon
# ...

# %%
df2 = df2.fillna(0)

# %%
df2['properties.name'] = df2['properties.Country'].apply(lambda x: x.title())

# %%
df2
# Out:
#                                   geometry.coordinates geometry.type  \
# 0    [[[[31.287890625000017, -22.40205078125001], [...  MultiPolygon
# 1    [[[[30.39609375, -15.64306640625], [30.2506835...  MultiPolygon
# 2    [[[[53.08564453125001, 16.648388671874997], [5...  MultiPolygon
# 3    [[[[104.06396484375, 10.390820312499997], [104...  MultiPolygon
# 4    [[[[-60.821191406249994, 9.138378906249997], [...  MultiPolygon
# 5    [[[[12.439160156250011, 41.898388671875], [12....  MultiPolygon
# 6    [[[[166.74580078125, -14.826855468750011], [16...  MultiPolygon
# 7    [[[[70.94677734375, 42.248681640624994], [70.9...  MultiPolygon
# 8    [[[[-53.37060546875, -33.7421875], [-53.419580...  MultiPolygon
# 9    [[[[162.98320312500005, 5.325732421874989], [1...  MultiPolygon
# 10   [[[[169.63505859375005, 5.830078125], [169.615...  MultiPolygon
# 11   [[[[145.70839843750002, 18.7625], [145.678125,...  MultiPolygon
# 12   [[[[-64.84501953124999, 18.330078125], [-64.91...  MultiPolygon
# ...

# %%
def nice_text(district):
    
    return f"Total: {district}"

# %%
df2['properties.headline'] = df2['total'].apply(lambda x: nice_text(x))

# %%
def text2(district):
    
    return "Contract: " + district

# %%
df2['properties.list'] = df2['contract'].astype(str).apply(lambda x: text2(x))

# %%
def text3(district):
    
    return "Monetary Gift: " + district

# %%
df2['properties.list2'] = df2['monetary_gift'].astype(str).apply(lambda x: text3(x))

# %%
def text4(district):
    
    return "Real Estate: " + district

# %%
df2['properties.list3'] = df2['real_estate'].astype(str).apply(lambda x: text4(x))

# %%
ok_json = json.loads(df2.to_json(orient='records'))

# %%
def process_to_geojson(file):
    geo_data = {"type": "FeatureCollection", "features":[]}
    for row in file:
        this_dict = {"type": "Feature", "properties":{}, "geometry": {}}
        for key, value in row.items():
            key_names = key.split('.')
            if key_names[0] == 'geometry':
                this_dict['geometry'][key_names[1]] = value
            if str(key_names[0]) == 'properties':
                this_dict['properties'][key_names[1]] = value
        geo_data['features'].append(this_dict)
    return geo_data

# %%
geo_format = process_to_geojson(ok_json)

# %%
#Variable name
with open('geo-data2.js', 'w') as outfile:
    outfile.write("var infoData = ")
#geojson output
with open('geo-data2.js', 'a') as outfile:
    json.dump(geo_format, outfile)

# %%
df2.head()
# Out:
#                                 geometry.coordinates geometry.type  \
# 0  [[[[31.287890625000017, -22.40205078125001], [...  MultiPolygon
# 1  [[[[30.39609375, -15.64306640625], [30.2506835...  MultiPolygon
# 2  [[[[53.08564453125001, 16.648388671874997], [5...  MultiPolygon
# 3  [[[[104.06396484375, 10.390820312499997], [104...  MultiPolygon
# 4  [[[[-60.821191406249994, 9.138378906249997], [...  MultiPolygon
#
#   properties.Country     type   contract  monetary_gift  real_estate  \
# 0           ZIMBABWE  Feature    32077.0        60301.0          0.0
# 1             ZAMBIA  Feature  4347979.0      9091654.0          0.0
# 2              YEMEN  Feature        0.0            0.0          0.0
# 3            VIETNAM  Feature  9748093.0      2051320.0          0.0
# 4          VENEZUELA  Feature  3000000.0       311132.0          0.0
#
#         total properties.name properties.headline      properties.list  \
# 0     92378.0        Zimbabwe      Total: 92378.0    Contract: 32077.0
# ...

# %%
df2.describe()
# Out:
#            contract  monetary_gift   real_estate         total
# count  2.450000e+02   2.450000e+02  2.450000e+02  2.450000e+02
# mean   2.578542e+07   1.749107e+07  1.760061e+04  4.329409e+07
# std    1.158908e+08   6.274158e+07  2.754835e+05  1.544619e+08
# min    0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00   3.000000e+02  0.000000e+00  7.571900e+04
# 75%    3.237250e+06   2.720885e+06  0.000000e+00  7.749483e+06
# max    1.404055e+09   5.446427e+08  4.312000e+06  1.478676e+09
